# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_features(dataframe, features):
    features_count = len(features)
    assert features_count > 0

    fig, axs = plt.subplots(features_count)
    
    if features_count == 1:
        pass

    for i, feature in enumerate(features):
        feature_ax = axs[i]

        data = dataframe[feature]

        data.plot(ax=feature_ax)
        plt.xticks(rotation=90)

# %%
features = ['people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred']
plot_features(df, features)

# %%
df = pd.read_csv("C:/Users/tanya/rus_search/rus-covid-data.csv").reset_index().set_index("date")

# %%
df["people_vaccinated_per_hundred"].plot() 
plt.xticks(rotation=90)
# Out:
# (array([250., 300., 350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(250.0, 0, '2020-10-07'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["people_fully_vaccinated_per_hundred"].plot() 
plt.xticks(rotation=90)
# Out:
# (array([350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["male_smokers"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["female_smokers"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["new_cases_smoothed_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["total_cases_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["total_deaths_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["new_deaths_smoothed_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["reproduction_rate"].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["new_tests_smoothed_per_thousand"].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["total_tests_per_thousand"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["positive_rate"].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["new_vaccinations_smoothed_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([250., 300., 350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(250.0, 0, '2020-10-07'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["total_vaccinations_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([250., 300., 350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(250.0, 0, '2020-10-07'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["people_vaccinated_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([250., 300., 350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(250.0, 0, '2020-10-07'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["people_fully_vaccinated_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["new_cases_per_million"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])

# %%
df["people_fully_vaccinated_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["total_boosters_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([580., 600., 620., 640., 660., 680., 700., 720., 740.]),
#  [Text(580.0, 0, '2021-09-02'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(620.0, 0, '2021-10-12'),
#   Text(640.0, 0, '2021-11-01'),
#   Text(660.0, 0, '2021-11-21'),
#   Text(680.0, 0, '2021-12-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(720.0, 0, '2022-01-20'),
#   Text(740.0, 0, '')])

# %%
df["new_people_vaccinated_smoothed_per_hundred"].plot()
plt.xticks(rotation=90)
# Out:
# (array([250., 300., 350., 400., 450., 500., 550., 600., 650., 700., 750.]),
#  [Text(250.0, 0, '2020-10-07'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(350.0, 0, '2021-01-15'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(450.0, 0, '2021-04-25'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(550.0, 0, '2021-08-03'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(650.0, 0, '2021-11-11'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(750.0, 0, '')])

# %%
df["stringency_index"].plot()
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,
#          800.]),
#  [Text(-100.0, 0, '2021-10-19'),
#   Text(0.0, 0, '2020-01-31'),
#   Text(100.0, 0, '2020-05-10'),
#   Text(200.0, 0, '2020-08-18'),
#   Text(300.0, 0, '2020-11-26'),
#   Text(400.0, 0, '2021-03-06'),
#   Text(500.0, 0, '2021-06-14'),
#   Text(600.0, 0, '2021-09-22'),
#   Text(700.0, 0, '2021-12-31'),
#   Text(800.0, 0, '')])
