# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
FULL_FEATURE_NAMES = ["people_vaccinated_per_hundred",
                     "people_fully_vaccinated_per_hundred", 
                     "male_smokers", 
                     "female_smokers", 
                     "new_cases_smoothed_per_million", 
                     "total_cases_per_million", 
                     "total_deaths_per_million", 
                     "new_deaths_smoothed_per_million", 
                     "reproduction_rate", 
                     "new_tests_smoothed_per_thousand", 
                     "total_tests_per_thousand", 
                     "positive_rate", 
                     "new_vaccinations_smoothed_per_million", 
                     "total_vaccinations_per_hundred", 
                     "new_cases_per_million", 
                     "total_boosters_per_hundred", 
                     "new_people_vaccinated_smoothed_per_hundred", 
                     "stringency_index", 
                     "diabetes_prevalence", 
                     "hospital_beds_per_thousand", 
                     "life_expectancy"]

FEATURE_NAMES = ["people_vaccinated_per_hundred", "people_fully_vaccinated_per_hundred"]

# %%
df = pd.read_csv(r'./rus-covid-data.csv').set_index('date')
df.head()
# Out:
#            iso_code continent location  total_cases  new_cases  \
# date
# 2020-01-31      RUS    Europe   Russia          2.0        2.0
# 2020-02-01      RUS    Europe   Russia          2.0        0.0
# 2020-02-02      RUS    Europe   Russia          2.0        0.0
# 2020-02-03      RUS    Europe   Russia          2.0        0.0
# 2020-02-04      RUS    Europe   Russia          2.0        0.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-31                 NaN           NaN         NaN                  NaN
# 2020-02-01                 NaN           NaN         NaN                  NaN
# 2020-02-02                 NaN           NaN         NaN                  NaN
# 2020-02-03                 NaN           NaN         NaN                  NaN
# 2020-02-04                 NaN           NaN         NaN                  NaN
#
#             total_cases_per_million  ...  female_smokers  male_smokers  \
# ...

# %%
def plot_f(dataframe, features, rows=5, plotsize=(3, 3), sharex=False):
    reduced_df = dataframe[features]
    
    cols = len(features) // rows
    if len(features) % rows > 0:
        cols += 1
    
    if len(features) // rows == 0:
        rows, cols = len(features), 1

    print(rows, cols)
    y_size, x_size = plotsize[0]*rows + 5, plotsize[1]*cols + 5
    axes = reduced_df.plot(subplots=True, 
                           layout=(rows, cols),
                           figsize=(y_size, x_size),
                           sharex=sharex,
                           rot=90)

# %%
plot_f(df, FULL_FEATURE_NAMES, plotsize=(5, 5), sharex=False)
# Out:
# 5 5
